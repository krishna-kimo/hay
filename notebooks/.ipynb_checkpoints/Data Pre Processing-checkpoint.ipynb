# %% [markdown]
# #### Data Process to convert single CSV file to multiple txt files.
# ---
#     - [ ] Read the CSV into Pandas
#     - [ ] Read each row what is required and write a txt file.
#
# ---
#     - Read only first 500 values for quick prototyping

# %%
import pandas as pd
import numpy as np

# %%
csv_file = '/home/krishna/Downloads/clean_total.csv'

data_df = pd.read_csv(csv_file, nrows=500)

# %%
data_df.shape
# Out:
# (500, 9)

# %%
data_df.head()
# Out:
#                                    paper_id  \
# 0  f6b29be971089bfe0916c64ab9fbddcec38a7436
# 1  005d189d5bd7ac01aee65e934fd3d5186a3f7b27
# 2  f905f78b32f63c6d14a79984dfb33f1b358b8ab4
# 3  607e0074d8ff40c272b958c2fe48793fedfc785e
# 4  72e25b728c6c62fb3a4e2c59c8ee48de4b5ee452
#
#                                                title  \
# 0  Faecal immunochemical testing (FIT): Sources o...
# 1  Relationship between Average Daily Temperature...
# 2  Multimerization of HIV-1 integrase hinges on c...
# 3  Virus shedding patterns in nasopharyngeal and ...
# 4  Phylogenetic Analysis of the Novel Coronavirus...
#
#                                              authors  \
# 0  Tim James, Brian D Nicholson, Rhiannon Marr, M...
# 1  Behzad Pirouz, Amirsina Golmohammadi, Hasti Sa...
# 2                        Meytal Galilee, Akram Alian
# 3  Ning Zhang, Yuhuan Gong, Fanping Meng, Yuhai B...
# 4                         Aditi Joshi, Sushmita Paul
#
#                                         affiliations  \
# 0  Tim James (Oxford University Hospitals NHS Fou...
# 1  Behzad Pirouz (University of Calabria, 87036, ...
# 2  Meytal Galilee (Technion -Israel Institute of ...
# 3  Ning Zhang, Yuhuan Gong (Anhui University, 10 ...
# 4  Aditi Joshi (Indian Institute of Technology Jo...
#
#                                             abstract  \
# 0  Abstract\n\nAims: To determine analytical capa...
# 1  Abstract\n\nThe rapid outbreak of the new Coro...
# 2  Abstract\n\nNew anti-AIDS treatments must be c...
# 3                                                NaN
# 4  Abstract\n\nRecently classified as a pandemic ...
#
#                                                 text  \
# 0  Introduction\n\nColorectal cancer is globally ...
# 1  Introduction\n\nThe outbreak of infectious dis...
# 2  \n\nIn the absence of a curative treatment, th...
# 3  \n\nthe author/funder, who has granted medRxiv...
# 4  \n\nThe pandemic of COVID-19 is taking a troll...
#
#                                         bibliography  \
# 0  Colorectal cancer Source: Globocan 2018 Number...
# 1  WHO, Coronavirus disease (COVID-2019) situatio...
# 2  HIV drug resistance against strand transfer in...
# 3  A Novel Coronavirus from Patients with 78 Pneu...
# 4  COVID-2019: The role of the NSP2 and NSP3 in i...
#
#                                          raw_authors  \
# 0  [{'first': 'Tim', 'middle': [], 'last': 'James...
# 1  [{'first': 'Behzad', 'middle': [], 'last': 'Pi...
# 2  [{'first': 'Meytal', 'middle': [], 'last': 'Ga...
# 3  [{'first': 'Ning', 'middle': [], 'last': 'Zhan...
# 4  [{'first': 'Aditi', 'middle': [], 'last': 'Jos...
#
#                                     raw_bibliography
# 0  {'BIBREF0': {'ref_id': 'b0', 'title': 'Colorec...
# 1  {'BIBREF0': {'ref_id': 'b0', 'title': 'WHO, Co...
# 2  {'BIBREF0': {'ref_id': 'b0', 'title': 'HIV dru...
# 3  {'BIBREF0': {'ref_id': 'b0', 'title': 'A Novel...
# 4  {'BIBREF0': {'ref_id': 'b0', 'title': 'COVID-2...

# %%
import re


def clean_wiki_text(text):
    # get rid of multiple new lines
    while "\n\n" in text:
        text = text.replace("\n\n", "\n")

    # remove extremely short lines
    text = text.split("\n")
    cleaned = []
    for l in text:
        if len(l) > 30:
            cleaned.append(l)
        elif l[:2] == "==" and l[-2:] == "==":
            cleaned.append(l)
    text = "\n".join(cleaned)

    # remove empty paragrahps
    text = re.sub(r"(==.*==\n\n\n)", "", text)

    return text

# %%
#colums = ['title', 'abstract', 'text', 'author', 'affliations', 'bibliography']
#data_df['comb_text'] = data_df[['title', 'abstract', 'text', 'authors', 'affiliations', 'bibliography']].agg(''.join, axis=1)
data_df["comb_text"] = data_df["title"].astype(str) + data_df["abstract"].astype(str) + data_df['text'].astype(str) \
                        + data_df['authors'].astype(str) + data_df['affiliations'].astype(str) + data_df['bibliography'].astype(str)

# %%
data_df.shape
# Out:
# (500, 10)

# %%
data_df.head(4)
# Out:
#                                    paper_id  \
# 0  f6b29be971089bfe0916c64ab9fbddcec38a7436
# 1  005d189d5bd7ac01aee65e934fd3d5186a3f7b27
# 2  f905f78b32f63c6d14a79984dfb33f1b358b8ab4
# 3  607e0074d8ff40c272b958c2fe48793fedfc785e
#
#                                                title  \
# 0  Faecal immunochemical testing (FIT): Sources o...
# 1  Relationship between Average Daily Temperature...
# 2  Multimerization of HIV-1 integrase hinges on c...
# 3  Virus shedding patterns in nasopharyngeal and ...
#
#                                              authors  \
# 0  Tim James, Brian D Nicholson, Rhiannon Marr, M...
# 1  Behzad Pirouz, Amirsina Golmohammadi, Hasti Sa...
# 2                        Meytal Galilee, Akram Alian
# 3  Ning Zhang, Yuhuan Gong, Fanping Meng, Yuhai B...
#
#                                         affiliations  \
# 0  Tim James (Oxford University Hospitals NHS Fou...
# 1  Behzad Pirouz (University of Calabria, 87036, ...
# 2  Meytal Galilee (Technion -Israel Institute of ...
# 3  Ning Zhang, Yuhuan Gong (Anhui University, 10 ...
#
#                                             abstract  \
# 0  Abstract\n\nAims: To determine analytical capa...
# 1  Abstract\n\nThe rapid outbreak of the new Coro...
# 2  Abstract\n\nNew anti-AIDS treatments must be c...
# 3                                                NaN
#
#                                                 text  \
# 0  Introduction\n\nColorectal cancer is globally ...
# 1  Introduction\n\nThe outbreak of infectious dis...
# 2  \n\nIn the absence of a curative treatment, th...
# 3  \n\nthe author/funder, who has granted medRxiv...
#
#                                         bibliography  \
# 0  Colorectal cancer Source: Globocan 2018 Number...
# 1  WHO, Coronavirus disease (COVID-2019) situatio...
# 2  HIV drug resistance against strand transfer in...
# 3  A Novel Coronavirus from Patients with 78 Pneu...
#
#                                          raw_authors  \
# 0  [{'first': 'Tim', 'middle': [], 'last': 'James...
# 1  [{'first': 'Behzad', 'middle': [], 'last': 'Pi...
# 2  [{'first': 'Meytal', 'middle': [], 'last': 'Ga...
# 3  [{'first': 'Ning', 'middle': [], 'last': 'Zhan...
#
#                                     raw_bibliography  \
# 0  {'BIBREF0': {'ref_id': 'b0', 'title': 'Colorec...
# 1  {'BIBREF0': {'ref_id': 'b0', 'title': 'WHO, Co...
# 2  {'BIBREF0': {'ref_id': 'b0', 'title': 'HIV dru...
# 3  {'BIBREF0': {'ref_id': 'b0', 'title': 'A Novel...
#
#                                            comb_text
# 0  Faecal immunochemical testing (FIT): Sources o...
# 1  Relationship between Average Daily Temperature...
# 2  Multimerization of HIV-1 integrase hinges on c...
# 3  Virus shedding patterns in nasopharyngeal and ...

# %%
data_df['comb_text'] = data_df['comb_text'].apply(clean_wiki_text)

# %%
data_df.head(4)
# Out:
#                                    paper_id  \
# 0  f6b29be971089bfe0916c64ab9fbddcec38a7436
# 1  005d189d5bd7ac01aee65e934fd3d5186a3f7b27
# 2  f905f78b32f63c6d14a79984dfb33f1b358b8ab4
# 3  607e0074d8ff40c272b958c2fe48793fedfc785e
#
#                                                title  \
# 0  Faecal immunochemical testing (FIT): Sources o...
# 1  Relationship between Average Daily Temperature...
# 2  Multimerization of HIV-1 integrase hinges on c...
# 3  Virus shedding patterns in nasopharyngeal and ...
#
#                                              authors  \
# 0  Tim James, Brian D Nicholson, Rhiannon Marr, M...
# 1  Behzad Pirouz, Amirsina Golmohammadi, Hasti Sa...
# 2                        Meytal Galilee, Akram Alian
# 3  Ning Zhang, Yuhuan Gong, Fanping Meng, Yuhai B...
#
#                                         affiliations  \
# 0  Tim James (Oxford University Hospitals NHS Fou...
# 1  Behzad Pirouz (University of Calabria, 87036, ...
# 2  Meytal Galilee (Technion -Israel Institute of ...
# 3  Ning Zhang, Yuhuan Gong (Anhui University, 10 ...
#
#                                             abstract  \
# 0  Abstract\n\nAims: To determine analytical capa...
# 1  Abstract\n\nThe rapid outbreak of the new Coro...
# 2  Abstract\n\nNew anti-AIDS treatments must be c...
# 3                                                NaN
#
#                                                 text  \
# 0  Introduction\n\nColorectal cancer is globally ...
# 1  Introduction\n\nThe outbreak of infectious dis...
# 2  \n\nIn the absence of a curative treatment, th...
# 3  \n\nthe author/funder, who has granted medRxiv...
#
#                                         bibliography  \
# 0  Colorectal cancer Source: Globocan 2018 Number...
# 1  WHO, Coronavirus disease (COVID-2019) situatio...
# 2  HIV drug resistance against strand transfer in...
# 3  A Novel Coronavirus from Patients with 78 Pneu...
#
#                                          raw_authors  \
# 0  [{'first': 'Tim', 'middle': [], 'last': 'James...
# 1  [{'first': 'Behzad', 'middle': [], 'last': 'Pi...
# 2  [{'first': 'Meytal', 'middle': [], 'last': 'Ga...
# 3  [{'first': 'Ning', 'middle': [], 'last': 'Zhan...
#
#                                     raw_bibliography  \
# 0  {'BIBREF0': {'ref_id': 'b0', 'title': 'Colorec...
# 1  {'BIBREF0': {'ref_id': 'b0', 'title': 'WHO, Co...
# 2  {'BIBREF0': {'ref_id': 'b0', 'title': 'HIV dru...
# 3  {'BIBREF0': {'ref_id': 'b0', 'title': 'A Novel...
#
#                                            comb_text
# 0  Faecal immunochemical testing (FIT): Sources o...
# 1  Relationship between Average Daily Temperature...
# 2  Multimerization of HIV-1 integrase hinges on c...
# 3  Virus shedding patterns in nasopharyngeal and ...

# %%
work_df = data_df[['paper_id', 'comb_text']]

# %%
work_df
# Out:
#                                      paper_id  \
# 0    f6b29be971089bfe0916c64ab9fbddcec38a7436
# 1    005d189d5bd7ac01aee65e934fd3d5186a3f7b27
# 2    f905f78b32f63c6d14a79984dfb33f1b358b8ab4
# 3    607e0074d8ff40c272b958c2fe48793fedfc785e
# 4    72e25b728c6c62fb3a4e2c59c8ee48de4b5ee452
# ..                                        ...
# 495  009ceadbb6f9f0d597b9516f0b9ca01e40231aad
# 496  d71ca9fa89e45d55933b8791b984c2b6f773f06d
# 497  278e2c52630f1dbbda6a79db15a2260510586150
# 498  5027853479ee6e85e1d48490fc224790f1a2c050
# 499  e7869e78d3208ab3208ad27210b973fb0f11e447
#
#                                              comb_text
# 0    Faecal immunochemical testing (FIT): Sources o...
# 1    Relationship between Average Daily Temperature...
# 2    Multimerization of HIV-1 integrase hinges on c...
# 3    Virus shedding patterns in nasopharyngeal and ...
# 4    Phylogenetic Analysis of the Novel Coronavirus...
# ..                                                 ...
# 495  Impact of COVID-19 pandemic on severity of ill...
# 496  Machine Learning Analysis of Chest CT Scan Ima...
# 497  PhyloFold: Precise and Swift Prediction of RNA...
# 498  Shotgun proteomics of SARS-CoV-2 infected cell...
# 499  Development and Validation of a Diagnostic Nom...
#
# [500 rows x 2 columns]

# %%
import os.path
base_path = '/home/krishna/projects/haystack/docs'
for index, row in work_df.iterrows():
    #print(row['paper_id'])
    file_name = str(row['paper_id']) + '.txt'
    file_path = os.path.join(base_path, file_name) 
    with open(file_path, "w") as f:
        f.write(row['comb_text'])
# Out:
# f6b29be971089bfe0916c64ab9fbddcec38a7436

# %%
#### Colorectal cancer is globally the third most incident malignancy
